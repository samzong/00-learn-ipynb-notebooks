# %%
pip install -U "ray[default]"
# Out:
# ...
#   Obtaining dependency information for ray[default] from https://files.pythonhosted.org/packages/d5/a4/27583a0f35806097619416fbf73a97ca451605f042ebc6783b72c1be6053/ray-2.7.1-cp38-cp38-macosx_10_15_x86_64.whl.metadata
# ...
#   Obtaining dependency information for click>=7.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/5e/5d/97afbafd9d584ff1b45fcb354a479a3609bd97f912f8f1f6c563cb1fae21/filelock-3.12.4-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for msgpack<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/26/84/93e3cee53a1c32cfa672c65adcfb725e6a2b29f7cf710f62e0cbff6bcfaa/msgpack-1.0.7-cp38-cp38-macosx_10_9_x86_64.whl.metadata
# ...

# %%
import ray
